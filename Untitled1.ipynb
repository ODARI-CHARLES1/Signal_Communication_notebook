# %%
import sympy as sp
import scienceplots
import matplotlib.pyplot as plt

plt.style.use(["science","no-latex"])

# %%
from sympy.abc import t,f

# %%
y=sp.exp(-t)*sp.Heaviside(t)
sp.plot(y,xlim=[0,5])
plt.show()

# %%
sp.fourier_transform(y,t,f).doit()
# Out:
# FourierTransform(exp(-t)*Heaviside(t), t, exp(-t)*Heaviside(t))

# %%
y=sp.exp(-t)*sp.exp(-sp.I*2*sp.pi*f*t)*sp.Heaviside(t)

# %%
y
# Out:
# exp(-t)*exp(-2*I*pi*t*exp(-t)*Heaviside(t))*Heaviside(t)

# %%
sp.integrate(y,(t,0,sp.oo)).doit()
# Out:
# Integral(exp(-t)*exp(-2*I*pi*t*exp(-t)*Heaviside(t))*Heaviside(t), (t, 0, oo))

# %%
y=1/(1+2*sp.pi*f)

# %%
y
# Out:
# 1/(1 + 2*pi*exp(-t)*Heaviside(t))

# %%
sp.plot(sp.Abs(y))

# %%
y=sp.Heaviside(t+sp.pi)-sp.Heaviside(t-sp.pi)

# %%
sp.plot(y,xlim=[-4,4])

# %%
sp.plot((sp.sinc(t)))

# %%
sp.Abs(4+4*sp.I)
# Out:
# 4*sqrt(2)

# %%
sp.sqrt(32)
# Out:
# 4*sqrt(2)

# %%
sp.plot(sp.exp(-t)*sp.sin(2*sp.pi*t)*sp.Heaviside(t))

# %%
sp.diff(sp.Heaviside(t),t)
# Out:
# DiracDelta(t)

# %%
a
