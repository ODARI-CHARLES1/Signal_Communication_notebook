# %%
import sympy as sp
import matplotlib.pyplot as plt
import scienceplots 
import numpy as np

# %%
from sympy.abc import t,f

# %%
Y=sp.sinc(sp.pi*f)

# %%
sp.plot(Y,xlim=[-1.5,1.5])

# %%
sp.plot(Y.subs(f,f-5),xlim=[3.5,6.5])
